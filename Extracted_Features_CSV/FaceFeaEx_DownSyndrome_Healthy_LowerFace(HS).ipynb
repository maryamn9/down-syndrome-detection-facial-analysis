# %%
import tensorflow as tf
from tensorflow.keras.applications import resnet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def load_and_preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img_array

# %%
from tensorflow.keras.applications import ResNet50 # Changed resnet50 to ResNet50

def extract_features(model, img_path):
    img_array = load_and_preprocess_image(img_path)
    features = model.predict(img_array)
    features = features.flatten()
    return features

# Load the pretrained resnet50
model = ResNet50(weights='imagenet', include_top=False, pooling='avg') # Changed resnet50 to ResNet50

# %%
#path containing the images for downsyndrome
image_dir = '/content/drive/MyDrive/Face_Fea_Extract/DownSyndrome/LowerFace(HS)'
image_paths = [os.path.join(image_dir, img) for img in os.listdir(image_dir) if img.endswith(('png', 'jpg', 'jpeg'))]

# Extract features for each image and save to a list
features_list = []
image_names = []
for img_path in image_paths:
    features = extract_features(model, img_path)
    features_list.append(features)
    image_names.append(os.path.basename(img_path))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# ...

# %%
#These line of code convert the features to csv files
features_df = pd.DataFrame(features_list)
features_df.insert(0, 'image_name', image_names)

#features_df.to_csv('resnet50_features_Down_Syndrome_LowerFace(HS).csv', index=False)
# path to save your features
from google.colab import files
features_df.to_csv('/content/drive/MyDrive/FaceFeaturesExtract-Resnet/DownSyndrome/LowerFace(HS).csv', index=False) # Changed df to features_df and added a file extension

#file_path = '/content/drive/MyDrive/FaceFeaturesExtract-Resnet/DownSyndrome/LowerFace(HS)'

# %%
#path containing the images for healthy
image_dir = '/content/drive/MyDrive/Face_Fea_Extract/Healthy/LowerFace(HS)'
image_paths = [os.path.join(image_dir, img) for img in os.listdir(image_dir) if img.endswith(('png', 'jpg', 'jpeg'))]

# Extract features for each image and save to a list
features_list = []
image_names = []
for img_path in image_paths:
    features = extract_features(model, img_path)
    features_list.append(features)
    image_names.append(os.path.basename(img_path))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# ...

# %%
features_df = pd.DataFrame(features_list)
features_df.insert(0, 'image_name', image_names)
#features_df.to_csv('resnet50_features_Healthy_LowerFace(HS).csv', index=False)
# path to save your action units
from google.colab import files
features_df.to_csv('/content/drive/MyDrive/FaceFeaturesExtract-Resnet/Healthy/LowerFace(HS).csv', index=False) # Changed df to features_df and added a file extension
#file_path = '/content/drive/MyDrive/FaceFeaturesExtract-Resnet/Healthy/LowerFace(HS)'
