# %%
# !pip install mediapipe opencv-python
import cv2
import mediapipe as mp
import numpy as np
import os
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 12.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.4 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Initialize MediaPipe Face Mesh
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1, min_detection_confidence=0.5)

# %%
# Define the input and output folders
input_folder = '/content/drive/MyDrive/Dissertation/DownSyndrome/DownSyndrome/DownSyndrome'
output_folder = '/content/drive/MyDrive/Face_Fea_Extract/DownSyndrome/Eyes'

# Create the output folder if it doesn't exist
#if not os.path.exists(output_folder):
    #os.makedirs(output_folder)

# %%
# Function to get bounding box for a set of points
def get_bounding_box(points, image_shape):
    x_coords = [p[0] for p in points]
    y_coords = [p[1] for p in points]
    x_min = max(0, min(x_coords))
    y_min = max(0, min(y_coords))
    x_max = min(image_shape[1], max(x_coords))
    y_max = min(image_shape[0], max(y_coords))
    return x_min, y_min, x_max - x_min, y_max - y_min

# %%
# Iterate over each image in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(input_folder, filename)

        # Load the image
        image = cv2.imread(image_path)
        rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Perform facial landmark detection
        results = face_mesh.process(rgb_image)

        if results.multi_face_landmarks:
            for face_landmarks in results.multi_face_landmarks:
                # Define landmarks for the eyes
                eyes_indices = [71,143,53,31,224,110,222,23,22,55,128,8,197,285,357,168,442,452,252,443,254,467,342,300,261,383,265,372,260]
                eyes_points = [(int(face_landmarks.landmark[idx].x * image.shape[1]), int(face_landmarks.landmark[idx].y * image.shape[0])) for idx in eyes_indices]

                # Get bounding box for the eyes points
                bbox = get_bounding_box(eyes_points, image.shape)
                x_min, y_min, width, height = bbox

                # Ensure bounding box is within image dimensions
                if x_min < 0 or y_min < 0 or x_min + width > image.shape[1] or y_min + height > image.shape[0]:
                    print(f"Skipping {filename}: Bounding box out of image boundaries")
                    continue

                # Extract the region
                eyes_region = image[y_min:y_min+height, x_min:x_min+width]

                # Check if region is not empty
                if eyes_region.size == 0:
                    print(f"Skipping {filename}: Empty region")
                    continue

                # Save the extracted region
                output_path = os.path.join(output_folder, f"eyes_{filename}")
                cv2.imwrite(output_path, eyes_region)

                print(f"Saved extracted eyes region to {output_path}")
# Out:
# /usr/local/lib/python3.10/dist-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Saved extracted eyes region to /content/drive/MyDrive/Face_Fea_Extract/DownSyndrome/Eyes/eyes_down_1429.jpg
# Saved extracted eyes region to /content/drive/MyDrive/Face_Fea_Extract/DownSyndrome/Eyes/eyes_down_1384.jpg
# Saved extracted eyes region to /content/drive/MyDrive/Face_Fea_Extract/DownSyndrome/Eyes/eyes_down_136.jpg
# Saved extracted eyes region to /content/drive/MyDrive/Face_Fea_Extract/DownSyndrome/Eyes/eyes_down_1381.jpg
# Saved extracted eyes region to /content/drive/MyDrive/Face_Fea_Extract/DownSyndrome/Eyes/eyes_down_1378.jpg
# Saved extracted eyes region to /content/drive/MyDrive/Face_Fea_Extract/DownSyndrome/Eyes/eyes_down_1385.jpg
# ...
